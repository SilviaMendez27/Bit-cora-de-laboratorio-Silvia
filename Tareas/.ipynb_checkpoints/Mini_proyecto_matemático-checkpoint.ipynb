# %% [markdown]
# # Mini proyecto matemático

# %%
import random 
Datos_random=[random.randint(1,100) for i in range(50)]

# %%
Promedio=sum(Datos_random)/len(Datos_random)
print (Promedio)
# Out:
# 50.56

# %%
maximo=max(Datos_aleatorios)
print(maximo)
# Out:
# 54

# %%
import matplotlib.pyplot as plt

plt.hist(Datos_random, bins=10)

plt.title("Distribución de datos aleatorios")
plt.xlabel("Valores")
plt.ylabel("Frecuencia")

plt.grid(True)

plt.savefig("grafica_datos_random.png", dpi=300)

plt.show()

# %% [markdown]
# **Interpretación:** Se generaron 50 datos de manera aleatoria entre 1 y 100, de los cuales se obtuvo el valor máximo y un promedio. El histograma muestra cómo se distribuyen los valores y se observa que el rango de 70 a 80 tiene mayor frecuencia que los otros.
